# %% [markdown]
# <a href="https://colab.research.google.com/github/JefCabnt/CPE-018---CPE31S2/blob/main/Prelim_Question_32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

image = cv2.imread('/content/drive/MyDrive/CPE018/circles.png')

gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

print('Image loaded and converted to grayscale successfully.')
# Out:
# Image loaded and converted to grayscale successfully.

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
circle = cv2.imread('/content/drive/MyDrive/CPE018/circles.png')
gray_img = cv2.cvtColor(circle, cv2.COLOR_BGR2GRAY)
img = cv2.medianBlur(gray_img, 35)
cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)
circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,100,param1=100,param2=30,minRadius=0,maxRadius=0)
circles = np.uint16(np.around(circles))

for i in circles[0,:]:
  cv2.circle(circle,(i[0],i[1]),i[2],(0,0,255),2)
cv2_imshow(circle)
# Out:
# <PIL.Image.Image image mode=RGB size=720x540>

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=720x540>

# %%
if circles is not None:
    for i in circles[0, :]:
        cv2.circle(image, (i[0], i[1]), i[2], (0, 0, 255), 2)

print('Circles drawn on the image.')
# Out:
# Circles drawn on the image.

# %%
output_path = '/content/drive/MyDrive/CPE018/circles_detected.png'
cv2.imwrite(output_path, image)
print(f'Image saved as {output_path}')
# Out:
# Image saved as /content/drive/MyDrive/CPE018/circles_detected.png

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=720x540>
